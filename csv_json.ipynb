# %%
import pandas as pd

df = pd.read_csv('best_model_results.csv')

df.to_json('model_results.json', orient='records', indent=2)

# %%
df
# Out:
#                          entity_urn ownership_status  headcount  \
# 0      urn:harmonic:company:3613480          PRIVATE         14
# 1      urn:harmonic:company:9609784          PRIVATE         36
# 2      urn:harmonic:company:1443095          PRIVATE         15
# 3       urn:harmonic:company:824671          PRIVATE         49
# 4       urn:harmonic:company:796251          PRIVATE         57
# ...                             ...              ...        ...
# 14891  urn:harmonic:company:1613688          PRIVATE         45
# 14892  urn:harmonic:company:3271796          PRIVATE         80
# 14893  urn:harmonic:company:9893408          PRIVATE        103
# 14894  urn:harmonic:company:3157979          PRIVATE         73
# 14895  urn:harmonic:company:3139652          PRIVATE        126
#
#        twitter_follower_count  linkedin_follower_count  funding_total  \
# 0                       257.0                      739       5.000000
# ...
